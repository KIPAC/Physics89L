# %% [markdown]
# # Experimental design, data presentation
#
# ### Goals:
#
# 1. We are just getting started. The goals here are to make sure that you can run a jupyter notebook, that you are comfortable with the format of the class, and to get you thinking about what we are trying to learn when we do experiments.
#
# ### Timing
#
# Try to finish this notebook in 15 minutes
#
# ### Question and Answer Template
#
# You can go to the link below, and do "file" -> "make a copy" to make yourself a google doc that you can use to fill in the answers to the question in this week's notebooks.
#
# https://docs.google.com/document/d/1Tz93aCo4PUu9vHXFm_sgaC5onF1zDKzWY_SBdij6se4/edit?usp=sharing

# %% [markdown]
# I have two black cats! They bring joy to my life. So, I was dismayed to see this figure from the Washington Post:

# %% [markdown]
# https://www.washingtonpost.com/business/2019/04/05/dog-owners-are-much-happier-than-cat-owners-survey-finds/

# %% [markdown]
# ![washington_post.jpg](attachment:washington_post.jpg)

# %% [markdown]
# The questions you should ask about this plot are questions I would like you to ask every time you see a graphical display of data.

# %% [markdown]
# ## Questions for discussion:
#
# #### 1.1 What can we learn just by looking at the chart?

# %% [markdown]
# #### Let's say I drew the conclusion from the chart that having a dog as a pet made people happier than having a cat.

# %% [markdown]
# #### 1.2 What are some questions to ask about the experimental procedure that would convince you that this conclusion is true?
#
# #### 1.3 What are some additional numbers you would want to know to support this conclusion?
